# %% [markdown]
# **Disclaimer**: this notebook's compatibility with StatsBomb event data 4.0.0 was last checked on December 30th, 2023.

# %%
import sys, pandera, multimethod
print(sys.version)
print("pandera:", pandera.__version__, "| multimethod:", multimethod.__version__)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# pandera: 0.17.2 | multimethod: 1.10

# %%
from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl
import pandas as pd

# %%
# %autoreload 0

# clean out mismatched versions
# !pip uninstall -y pandera multimethod

# install versions that work together
# !pip install "pandera==0.17.2" "multimethod==1.10.0" tqdm
# Out:
# Found existing installation: pandera 0.17.2
# Uninstalling pandera-0.17.2:
#   Successfully uninstalled pandera-0.17.2
# Found existing installation: multimethod 1.10
# Uninstalling multimethod-1.10:
#   Successfully uninstalled multimethod-1.10
# Collecting pandera==0.17.2
#   Using cached pandera-0.17.2-py3-none-any.whl.metadata (15 kB)
# Collecting multimethod==1.10.0
#   Using cached multimethod-1.10-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: tqdm in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (25.0)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (2.3.2)
# Requirement already satisfied: pydantic in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (2.11.7)
# Requirement already satisfied: typeguard>=3.0.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (4.4.4)
# Requirement already satisfied: typing-inspect>=0.6.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (1.17.3)
# Requirement already satisfied: colorama in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas>=1.2.0->pandera==0.17.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas>=1.2.0->pandera==0.17.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas>=1.2.0->pandera==0.17.2) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pandera==0.17.2) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from typeguard>=3.0.2->pandera==0.17.2) (4.15.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from typing-inspect>=0.6.0->pandera==0.17.2) (1.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pydantic->pandera==0.17.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pydantic->pandera==0.17.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pydantic->pandera==0.17.2) (0.4.1)
# Using cached pandera-0.17.2-py3-none-any.whl (203 kB)
# Using cached multimethod-1.10-py3-none-any.whl (9.9 kB)
# Installing collected packages: multimethod, pandera
#
#    -------------------- ------------------- 1/2 [pandera]
#    -------------------- ------------------- 1/2 [pandera]
#    -------------------- ------------------- 1/2 [pandera]
#    -------------------- ------------------- 1/2 [pandera]
#    -------------------- ------------------- 1/2 [pandera]
#    -------------------- ------------------- 1/2 [pandera]
#    -------------------- ------------------- 1/2 [pandera]
#    ---------------------------------------- 2/2 [pandera]
#
# Successfully installed multimethod-1.10 pandera-0.17.2

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from tqdm) (0.4.6)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
import os
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")
import tqdm

# %%
# !pip install "pandera==0.17.2" "multimethod==1.10.0" tqdm
# Out:
# Requirement already satisfied: pandera==0.17.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (0.17.2)
# Collecting multimethod==1.10.0
#   Downloading multimethod-1.10-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: tqdm in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (25.0)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (2.3.2)
# Requirement already satisfied: pydantic in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (2.11.7)
# Requirement already satisfied: typeguard>=3.0.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (4.4.4)
# Requirement already satisfied: typing-inspect>=0.6.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandera==0.17.2) (1.17.3)
# Requirement already satisfied: colorama in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas>=1.2.0->pandera==0.17.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas>=1.2.0->pandera==0.17.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas>=1.2.0->pandera==0.17.2) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pandera==0.17.2) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from typeguard>=3.0.2->pandera==0.17.2) (4.15.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from typing-inspect>=0.6.0->pandera==0.17.2) (1.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pydantic->pandera==0.17.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pydantic->pandera==0.17.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pydantic->pandera==0.17.2) (0.4.1)
# Downloading multimethod-1.10-py3-none-any.whl (9.9 kB)
# Installing collected packages: multimethod
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 2.0
#     Uninstalling multimethod-2.0:
#       Successfully uninstalled multimethod-2.0
# Successfully installed multimethod-1.10

# %%
pip install statsbombpy
# Out:
# Collecting statsbombpy
#   Downloading statsbombpy-1.16.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: pandas in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from statsbombpy) (2.3.2)
# Requirement already satisfied: requests in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from statsbombpy) (2.32.5)
# Collecting requests-cache (from statsbombpy)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting inflect (from statsbombpy)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: joblib in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from statsbombpy) (1.5.2)
# Collecting more_itertools>=8.5.0 (from inflect->statsbombpy)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from inflect->statsbombpy) (4.4.4)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (4.15.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas->statsbombpy) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas->statsbombpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->statsbombpy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->statsbombpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->statsbombpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->statsbombpy) (2025.8.3)
# Requirement already satisfied: attrs>=21.2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests-cache->statsbombpy) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache->statsbombpy)
#   Downloading cattrs-25.2.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests-cache->statsbombpy) (4.4.0)
# Collecting url-normalize>=1.4 (from requests-cache->statsbombpy)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading statsbombpy-1.16.0-py3-none-any.whl (16 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading cattrs-25.2.0-py3-none-any.whl (70 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, more_itertools, cattrs, requests-cache, inflect, statsbombpy
#
#    ---------------------------------------- 0/6 [url-normalize]
#    ------------- -------------------------- 2/6 [cattrs]
#    ------------- -------------------------- 2/6 [cattrs]
#    ------------- -------------------------- 2/6 [cattrs]
#    -------------------- ------------------- 3/6 [requests-cache]
#    -------------------- ------------------- 3/6 [requests-cache]
#    -------------------- ------------------- 3/6 [requests-cache]
#    --------------------------------- ------ 5/6 [statsbombpy]
#    ---------------------------------------- 6/6 [statsbombpy]
#
# Successfully installed cattrs-25.2.0 inflect-7.5.0 more_itertools-10.8.0 requests-cache-1.2.1 statsbombpy-1.16.0 url-normalize-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})
comps = SBL.competitions()
comps[["competition_name","season_name"]].head()
# Out:
#          competition_name season_name
# 0           1. Bundesliga   2023/2024
# 1           1. Bundesliga   2015/2016
# 2  African Cup of Nations        2023
# 3        Champions League   2018/2019
# 4        Champions League   2017/2018

# %%
# %load_ext autoreload
# %autoreload 2
from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl

# %% [markdown]
# ## Set up the StatsBombLoader

# %%
# Use this if you want to use the free public statsbomb data
# or provide credentials to access the API
SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})

# # Uncomment the code below if you have a local folder on your computer with statsbomb data
# datafolder = "../data/statsbomb-epl-1718" # Example of local folder with statsbomb data
# SBL = StatsBombLoader(root=datafolder, getter="local")

# %%
# View all available competitions
competitions = SBL.competitions()
set(competitions.competition_name)
# Out:
# {'1. Bundesliga',
#  'African Cup of Nations',
#  'Champions League',
#  'Copa America',
#  'Copa del Rey',
#  "FA Women's Super League",
#  'FIFA U20 World Cup',
#  'FIFA World Cup',
#  'Indian Super league',
#  'La Liga',
#  'Liga Profesional',
#  'Ligue 1',
#  'Major League Soccer',
#  'NWSL',
#  'North American League',
#  'Premier League',
#  'Serie A',
#  'UEFA Euro',
#  'UEFA Europa League',
#  "UEFA Women's Euro",
#  "Women's World Cup"}

# %%
# Fifa world cup
selected_competitions = competitions[
    (competitions.competition_name == "FIFA World Cup")
    & (competitions.season_name == "2018")
]

# # Messi data
# selected_competitions = competitions[competitions.competition_name == "La Liga"]

# # FA Women's Super League
# selected_competitions = competitions[competitions.competition_name == "FA Women's Super League"]

selected_competitions
# Out:
#     season_id  competition_id competition_name   country_name  \
# 30          3              43   FIFA World Cup  International
#
#    competition_gender season_name
# 30               male        2018

# %%
# Get games from all selected competitions
games = pd.concat([
    SBL.games(row.competition_id, row.season_id)
    for row in selected_competitions.itertuples()
])
games[["home_team_id", "away_team_id", "game_date", "home_score", "away_score"]]
# Out:
#     home_team_id  away_team_id           game_date  home_score  away_score
# 0            769           768 2018-07-03 20:00:00           1           1
# 1            768           782 2018-06-28 20:00:00           0           1
# 2            790           773 2018-07-03 16:00:00           1           0
# 3            797           780 2018-06-25 20:00:00           1           1
# 4            780           788 2018-06-20 14:00:00           1           0
# ..           ...           ...                 ...         ...         ...
# 59           796           774 2018-06-19 20:00:00           3           1
# 60           796           785 2018-07-07 20:00:00           2           2
# 61           776           771 2018-06-26 16:00:00           0           0
# 62           778           787 2018-06-24 17:00:00           2           2
# 63           799           774 2018-06-25 16:00:00           2           1
#
# [64 rows x 5 columns]

# %% [markdown]
# ## Load and convert match data

# %%
games_verbose = tqdm.tqdm(list(games.itertuples()), desc="Loading game data")
teams, players = [], []
actions = {}
for game in games_verbose:
    # load data
    teams.append(SBL.teams(game.game_id))
    players.append(SBL.players(game.game_id))
    events = SBL.events(game.game_id)
    # convert data
    actions[game.game_id] = spadl.statsbomb.convert_to_actions(
        events, 
        home_team_id=game.home_team_id,
        xy_fidelity_version=1,
        shot_fidelity_version=1
    )

teams = pd.concat(teams).drop_duplicates(subset="team_id")
players = pd.concat(players)
# Out:
# Loading game data:   0%|                                                                                                                                   | 0/64 [00:00<?, ?it/s]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   2%|█▉                                                                                                                         | 1/64 [00:01<01:55,  1.84s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   3%|███▊                                                                                                                       | 2/64 [00:03<01:53,  1.83s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   5%|█████▊                                                                                                                     | 3/64 [00:05<01:49,  1.80s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   6%|███████▋                                                                                                                   | 4/64 [00:07<01:43,  1.73s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   8%|█████████▌                                                                                                                 | 5/64 [00:08<01:42,  1.74s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   9%|███████████▌                                                                                                               | 6/64 [00:10<01:42,  1.76s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  11%|█████████████▍                                                                                                             | 7/64 [00:12<01:41,  1.79s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  12%|███████████████▍                                                                                                           | 8/64 [00:14<01:39,  1.77s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  14%|█████████████████▎                                                                                                         | 9/64 [00:15<01:37,  1.78s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  16%|███████████████████                                                                                                       | 10/64 [00:17<01:35,  1.77s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  17%|████████████████████▉                                                                                                     | 11/64 [00:19<01:30,  1.71s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  19%|██████████████████████▉                                                                                                   | 12/64 [00:21<01:32,  1.78s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  20%|████████████████████████▊                                                                                                 | 13/64 [00:23<01:30,  1.78s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  22%|██████████████████████████▋                                                                                               | 14/64 [00:24<01:30,  1.81s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  23%|████████████████████████████▌                                                                                             | 15/64 [00:26<01:26,  1.77s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  25%|██████████████████████████████▌                                                                                           | 16/64 [00:28<01:22,  1.73s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  27%|████████████████████████████████▍                                                                                         | 17/64 [00:29<01:18,  1.66s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍         | 59/64 [01:42<00:09,  1.83s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍       | 60/64 [01:44<00:07,  1.79s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 61/64 [01:46<00:05,  1.83s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 62/64 [01:47<00:03,  1.77s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 63/64 [01:49<00:01,  1.71s/it]C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\OneDrive\Documents\GitHub\Group-60\socceraction-master\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [01:51<00:00,  1.74s/it]

# %% [markdown]
# ## Store converted spadl data in a h5-file

# %%
pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.10.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from tables) (1.26.4)
# Collecting numexpr>=2.6.2 (from tables)
#   Downloading numexpr-2.11.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: packaging in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from tables) (25.0)
# Collecting py-cpuinfo (from tables)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables)
#   Downloading blosc2-3.7.2-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from tables) (4.15.0)
# Collecting ndindex (from blosc2>=2.3.0->tables)
#   Downloading ndindex-1.10.0-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables)
#   Downloading msgpack-1.1.1-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: platformdirs in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from blosc2>=2.3.0->tables) (4.4.0)
# Requirement already satisfied: requests in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from blosc2>=2.3.0->tables) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->blosc2>=2.3.0->tables) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->blosc2>=2.3.0->tables) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->blosc2>=2.3.0->tables) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from requests->blosc2>=2.3.0->tables) (2025.8.3)
# Downloading tables-3.10.2-cp311-cp311-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ------------------ --------------------- 2.9/6.4 MB 24.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 26.3 MB/s  0:00:00
# Downloading blosc2-3.7.2-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 18.3 MB/s  0:00:00
# Downloading numexpr-2.11.0-cp311-cp311-win_amd64.whl (146 kB)
# Downloading msgpack-1.1.1-cp311-cp311-win_amd64.whl (72 kB)
# Downloading ndindex-1.10.0-cp311-cp311-win_amd64.whl (156 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, numexpr, ndindex, msgpack, blosc2, tables
#
#    ------ --------------------------------- 1/6 [numexpr]
#    ------------- -------------------------- 2/6 [ndindex]
#    ------------- -------------------------- 2/6 [ndindex]
#    ------------- -------------------------- 2/6 [ndindex]
#    -------------------------- ------------- 4/6 [blosc2]
#    -------------------------- ------------- 4/6 [blosc2]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    ---------------------------------------- 6/6 [tables]
#
# Successfully installed blosc2-3.7.2 msgpack-1.1.1 ndindex-1.10.0 numexpr-2.11.0 py-cpuinfo-9.0.0 tables-3.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
datafolder = "../data-fifa"

# Create data folder if it doesn't exist
if not os.path.exists(datafolder):
    os.mkdir(datafolder)
    print(f"Directory {datafolder} created.")

spadl_h5 = os.path.join(datafolder, "spadl-statsbomb.h5")

# Store all spadl data in h5-file
with pd.HDFStore(spadl_h5) as spadlstore:
    spadlstore["competitions"] = selected_competitions
    spadlstore["games"] = games
    spadlstore["teams"] = teams
    spadlstore["players"] = players[['player_id', 'player_name', 'nickname']].drop_duplicates(subset='player_id')
    spadlstore["player_games"] = players[['player_id', 'game_id', 'team_id', 'is_starter', 'starting_position_id', 'starting_position_name', 'minutes_played']]
    for game_id in actions.keys():
        spadlstore[f"actions/game_{game_id}"] = actions[game_id]

# %% [markdown]
# ## Plot the spadl data
# Extra library required: ```pip install matplotsoccer```

# %%
pip install matplotsoccer
# Out:
# Collecting matplotsoccer
#   Downloading matplotsoccer-0.0.8.tar.gz (5.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: matplotsoccer
#   Building wheel for matplotsoccer (pyproject.toml): started
#   Building wheel for matplotsoccer (pyproject.toml): finished with status 'done'
#   Created wheel for matplotsoccer: filename=matplotsoccer-0.0.8-py3-none-any.whl size=6032 sha256=654fb20a275ac08d9a74fb8181ba290619bc7059a3d92499275feade8ad347af
#   Stored in directory: c:\users\arya1\appdata\local\pip\cache\wheels\5f\96\51\a91e3de14cbbb035d664ca08bf412678bda3e5c7864f9ba66d
# Successfully built matplotsoccer
# Installing collected packages: matplotsoccer
# Successfully installed matplotsoccer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
with pd.HDFStore(spadl_h5) as spadlstore:
    games = (
        spadlstore["games"]
        .merge(spadlstore["competitions"], how='left')
        .merge(spadlstore["teams"].add_prefix('home_'), how='left')
        .merge(spadlstore["teams"].add_prefix('away_'), how='left'))
    # Select England vs Belgium game at World Cup
    game = games[(games.competition_name == "FIFA World Cup") 
                  & (games.away_team_name == "England")
                  & (games.home_team_name == "Belgium")]
    game_id = game.game_id.values[0]
    actions = (
        spadlstore[f"actions/game_{game_id}"]
        .merge(spadl.actiontypes_df(), how="left")
        .merge(spadl.results_df(), how="left")
        .merge(spadl.bodyparts_df(), how="left")
        .merge(spadlstore["players"], how="left")
        .merge(spadlstore["teams"], how="left")
    )

# use nickname if available else use full name
actions["player_name"] = actions[["nickname", "player_name"]].apply(lambda x: x.iloc[0] if x.iloc[0] else x.iloc[1], axis=1)
del actions['nickname']
actions[:5]
# Out:
#    game_id                     original_event_id  period_id  time_seconds  \
# 0     8657  84438495-6341-4eba-bf90-82db1f6703fb          1         0.533
# 1     8657  6f02abb4-0b81-4531-be11-6bf6ea7e695b          1         1.252
# 2     8657  34b355a6-8b5f-4954-8dfd-fcc77df5c40c          1         2.133
# 3     8657  29b70f75-5970-491c-acc7-5dbfb353200c          1         3.732
# 4     8657  8fd1ffd0-b984-4823-ab2c-f249c04adc12          1         4.933
#
#    team_id  player_id  start_x  start_y    end_x   end_y  type_id  result_id  \
# 0      782     3289.0  52.9375   33.575  44.1875  33.575        0          1
# 1      782     5642.0  44.1875   33.575  44.1875  34.425       21          1
# 2      782     5642.0  44.1875   34.425  31.9375  53.125        0          1
# 3      782     3077.0  31.9375   53.125  28.4375  53.125       21          1
# 4      782     3077.0  28.4375   53.125  24.0625  38.675        0          1
#
#    bodypart_id  action_id type_name result_name bodypart_name     player_name  \
# 0            5          0      pass     success    foot_right   Romelu Lukaku
# 1            0          1   dribble     success          foot     Axel Witsel
# 2            5          2      pass     success    foot_right     Axel Witsel
# 3            0          3   dribble     success          foot  Jan Vertonghen
# 4            4          4      pass     success     foot_left  Jan Vertonghen
#
#   team_name
# 0   Belgium
# 1   Belgium
# 2   Belgium
# 3   Belgium
# 4   Belgium

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp311-cp311-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\arya1\onedrive\documents\github\group-60\socceraction-master\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.6-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------- ----------------------- 3.4/8.1 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 27.8 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 25.7 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------  6.8/7.0 MB 42.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 33.1 MB/s  0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------- ----------------- 4/7 [cycler]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.10.6 pillow-11.3.0 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotsoccer

# Select the 5 actions preceding the 2-0
shot = 2201
a = actions[shot-4:shot+1].copy()

# Print the game date and timestamp of the goal
g = game.iloc[0]
minute = int((a.period_id.values[0]-1) * 45 + a.time_seconds.values[0] // 60)
game_info = f"{g.game_date} {g.home_team_name} {g.home_score}-{g.away_score} {g.away_team_name} {minute + 1}'"
print(game_info)

# Plot the actions
def nice_time(row):
    minute = int((row.period_id-1)*45 +row.time_seconds // 60)
    second = int(row.time_seconds % 60)
    return f"{minute}m{second}s"

a["nice_time"] = a.apply(nice_time, axis=1)
labels = a[["nice_time", "type_name", "player_name", "team_name"]]

ax = matplotsoccer.actions(
    location=a[["start_x", "start_y", "end_x", "end_y"]],
    action_type=a.type_name,
    team= a.team_name,
    result= a.result_name == "success",
    label=labels,
    labeltitle=["time", "actiontype", "player", "team"],
    zoom=False,
    figsize=6
)
# Out:
# 2018-07-14 16:00:00 Belgium 2-0 England 82'
