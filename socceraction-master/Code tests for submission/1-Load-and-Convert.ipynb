# %% [markdown]
# **Disclaimer**: this notebook's compatibility with StatsBomb event data 4.0.0 was last checked on December 30th, 2023.

# %%
# %pip install pandas pandera "multimethod<2" socceraction statsbombpy tqdm requests matplotlib matplotsoccer tables
# Out:
# Requirement already satisfied: pandas in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (2.3.3)
# Requirement already satisfied: pandera in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (0.17.2)
# Requirement already satisfied: multimethod<2 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (1.12)
# Requirement already satisfied: socceraction in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (1.5.3)
# Requirement already satisfied: statsbombpy in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (1.16.0)
# Requirement already satisfied: tqdm in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (4.67.1)
# Requirement already satisfied: requests in c:\users\arya1\appdata\roaming\python\python311\site-packages (2.32.5)
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: matplotsoccer in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (0.0.8)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from pandera) (25.0)
# Requirement already satisfied: pydantic in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pandera) (2.12.4)
# Requirement already satisfied: typeguard>=3.0.2 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pandera) (4.4.4)
# Requirement already satisfied: typing-inspect>=0.6.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pandera) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pandera) (2.0.1)
# Requirement already satisfied: lxml<5.0.0,>=4.9.3 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from socceraction) (4.9.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.1 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from socceraction) (1.7.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2.0.0,>=1.3.1->socceraction) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2.0.0,>=1.3.1->socceraction) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2.0.0,>=1.3.1->socceraction) (3.6.0)
# Requirement already satisfied: requests-cache in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from statsbombpy) (7.5.0)
# Requirement already satisfied: colorama in c:\users\arya1\appdata\roaming\python\python311\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests) (2025.11.12)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp311-cp311-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from typeguard>=3.0.2->pandera) (4.15.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect>=0.6.0->pandera) (1.1.0)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from inflect->statsbombpy) (10.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pydantic->pandera) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pydantic->pandera) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from pydantic->pandera) (0.4.2)
# Requirement already satisfied: attrs>=21.2 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests-cache->statsbombpy) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from requests-cache->statsbombpy) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests-cache->statsbombpy) (4.5.0)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from requests-cache->statsbombpy) (2.2.1)
# Downloading matplotlib-3.10.7-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------------------- -------- 6.3/8.1 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 38.7 MB/s  0:00:00
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 43.8 MB/s  0:00:00
# Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-12.0.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 53.9 MB/s  0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")

import tqdm
import sys
import matplotsoccer

from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl

# %%
SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})
comps = SBL.competitions()
comps[["competition_name","season_name"]].head()
# Out:
#          competition_name season_name
# 0           1. Bundesliga   2023/2024
# 1           1. Bundesliga   2015/2016
# 2  African Cup of Nations        2023
# 3        Champions League   2018/2019
# 4        Champions League   2017/2018

# %% [markdown]
# ## Set up the StatsBombLoader

# %%
# Use this if you want to use the free public statsbomb data
# or provide credentials to access the API
SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})

# %%
# View all available competitions
competitions = SBL.competitions()
set(competitions.competition_name)
# Out:
# {'1. Bundesliga',
#  'African Cup of Nations',
#  'Champions League',
#  'Copa America',
#  'Copa del Rey',
#  "FA Women's Super League",
#  'FIFA U20 World Cup',
#  'FIFA World Cup',
#  'Indian Super league',
#  'La Liga',
#  'Liga Profesional',
#  'Ligue 1',
#  'Major League Soccer',
#  'NWSL',
#  'North American League',
#  'Premier League',
#  'Serie A',
#  'UEFA Euro',
#  'UEFA Europa League',
#  "UEFA Women's Euro",
#  "Women's World Cup"}

# %%
# Fifa world cup
selected_competitions = competitions[
    (competitions.competition_name == "FIFA World Cup")
    & (competitions.season_name == "2018")
]

# # Messi data
# selected_competitions = competitions[competitions.competition_name == "La Liga"]

# # FA Women's Super League
# selected_competitions = competitions[competitions.competition_name == "FA Women's Super League"]

selected_competitions
# Out:
#     season_id  competition_id competition_name   country_name  \
# 30          3              43   FIFA World Cup  International
#
#    competition_gender season_name
# 30               male        2018

# %%
# Get games from all selected competitions
games = pd.concat([
    SBL.games(row.competition_id, row.season_id)
    for row in selected_competitions.itertuples()
])
games[["home_team_id", "away_team_id", "game_date", "home_score", "away_score"]]
# Out:
#     home_team_id  away_team_id           game_date  home_score  away_score
# 0            769           768 2018-07-03 20:00:00           1           1
# 1            768           782 2018-06-28 20:00:00           0           1
# 2            790           773 2018-07-03 16:00:00           1           0
# 3            797           780 2018-06-25 20:00:00           1           1
# 4            780           788 2018-06-20 14:00:00           1           0
# ..           ...           ...                 ...         ...         ...
# 59           796           774 2018-06-19 20:00:00           3           1
# 60           796           785 2018-07-07 20:00:00           2           2
# 61           776           771 2018-06-26 16:00:00           0           0
# 62           778           787 2018-06-24 17:00:00           2           2
# 63           799           774 2018-06-25 16:00:00           2           1
#
# [64 rows x 5 columns]

# %% [markdown]
# ## Load and convert match data

# %%
games_verbose = tqdm.tqdm(list(games.itertuples()), desc="Loading game data")
teams, players = [], []
actions = {}
for game in games_verbose:
    # load data
    teams.append(SBL.teams(game.game_id))
    players.append(SBL.players(game.game_id))
    events = SBL.events(game.game_id)
    # convert data
    actions[game.game_id] = spadl.statsbomb.convert_to_actions(
        events, 
        home_team_id=game.home_team_id,
        xy_fidelity_version=1,
        shot_fidelity_version=1
    )

teams = pd.concat(teams).drop_duplicates(subset="team_id")
players = pd.concat(players)
# Out:
# Loading game data:   0%|                                                                        | 0/64 [00:00<?, ?it/s]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   2%|█                                                               | 1/64 [00:01<01:29,  1.43s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   3%|██                                                              | 2/64 [00:02<01:27,  1.41s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   5%|███                                                             | 3/64 [00:04<01:26,  1.42s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   6%|████                                                            | 4/64 [00:05<01:23,  1.39s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   8%|█████                                                           | 5/64 [00:06<01:22,  1.39s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:   9%|██████                                                          | 6/64 [00:08<01:24,  1.46s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  11%|███████                                                         | 7/64 [00:10<01:24,  1.48s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  12%|████████                                                        | 8/64 [00:11<01:22,  1.47s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  14%|█████████                                                       | 9/64 [00:13<01:21,  1.48s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  16%|█████████▊                                                     | 10/64 [00:14<01:21,  1.51s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  17%|██████████▊                                                    | 11/64 [00:16<01:18,  1.48s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  19%|███████████▊                                                   | 12/64 [00:17<01:15,  1.45s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  20%|████████████▊                                                  | 13/64 [00:18<01:13,  1.45s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  22%|█████████████▊                                                 | 14/64 [00:20<01:15,  1.51s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  23%|██████████████▊                                                | 15/64 [00:21<01:12,  1.48s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  25%|███████████████▊                                               | 16/64 [00:23<01:11,  1.50s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  27%|████████████████▋                                              | 17/64 [00:24<01:07,  1.43s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  28%|█████████████████▋                                             | 18/64 [00:26<01:07,  1.47s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  91%|█████████████████████████████████████████████████████████      | 58/64 [01:23<00:08,  1.46s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  92%|██████████████████████████████████████████████████████████     | 59/64 [01:24<00:07,  1.48s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  94%|███████████████████████████████████████████████████████████    | 60/64 [01:26<00:05,  1.45s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  95%|████████████████████████████████████████████████████████████   | 61/64 [01:27<00:04,  1.46s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  97%|█████████████████████████████████████████████████████████████  | 62/64 [01:29<00:02,  1.45s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data:  98%|██████████████████████████████████████████████████████████████ | 63/64 [01:30<00:01,  1.43s/it]C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\data\statsbomb\loader.py:338: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# C:\Users\Arya1\AppData\Local\Programs\Python\Python311\Lib\site-packages\socceraction\spadl\statsbomb.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events["extra"].fillna({}, inplace=True)
# Loading game data: 100%|███████████████████████████████████████████████████████████████| 64/64 [01:32<00:00,  1.44s/it]

# %% [markdown]
# ## Store converted spadl data in a h5-file

# %%
pip install tables
# Out:
# Collecting tables
#   Using cached tables-3.10.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\arya1\appdata\local\programs\python\python311\lib\site-packages (from tables) (1.26.4)
# Collecting numexpr>=2.6.2 (from tables)
#   Downloading numexpr-2.14.1-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: packaging in c:\users\arya1\appdata\roaming\python\python311\site-packages (from tables) (25.0)
# Collecting py-cpuinfo (from tables)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables)
#   Downloading blosc2-3.11.1-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from tables) (4.15.0)
# Collecting ndindex (from blosc2>=2.3.0->tables)
#   Using cached ndindex-1.10.0-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables)
#   Downloading msgpack-1.1.2-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs in c:\users\arya1\appdata\roaming\python\python311\site-packages (from blosc2>=2.3.0->tables) (4.5.0)
# Requirement already satisfied: requests in c:\users\arya1\appdata\roaming\python\python311\site-packages (from blosc2>=2.3.0->tables) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests->blosc2>=2.3.0->tables) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests->blosc2>=2.3.0->tables) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests->blosc2>=2.3.0->tables) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arya1\appdata\roaming\python\python311\site-packages (from requests->blosc2>=2.3.0->tables) (2025.11.12)
# Using cached tables-3.10.2-cp311-cp311-win_amd64.whl (6.4 MB)
# Downloading blosc2-3.11.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 21.7 MB/s  0:00:00
# Downloading numexpr-2.14.1-cp311-cp311-win_amd64.whl (160 kB)
# Downloading msgpack-1.1.2-cp311-cp311-win_amd64.whl (71 kB)
# Using cached ndindex-1.10.0-cp311-cp311-win_amd64.whl (156 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, numexpr, ndindex, msgpack, blosc2, tables
#
#    -------------------- ------------------- 3/6 [msgpack]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    --------------------------------- ------ 5/6 [tables]
#    ---------------------------------------- 6/6 [tables]
#
# Successfully installed blosc2-3.11.1 msgpack-1.1.2 ndindex-1.10.0 numexpr-2.14.1 py-cpuinfo-9.0.0 tables-3.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
datafolder = "../data-fifa"

# Create data folder if it doesn't exist
if not os.path.exists(datafolder):
    os.mkdir(datafolder)
    print(f"Directory {datafolder} created.")

spadl_h5 = os.path.join(datafolder, "spadl-statsbomb.h5")

# Store all spadl data in h5-file
with pd.HDFStore(spadl_h5) as spadlstore:
    spadlstore["competitions"] = selected_competitions
    spadlstore["games"] = games
    spadlstore["teams"] = teams
    spadlstore["players"] = players[['player_id', 'player_name', 'nickname']].drop_duplicates(subset='player_id')
    spadlstore["player_games"] = players[['player_id', 'game_id', 'team_id', 'is_starter', 'starting_position_id', 'starting_position_name', 'minutes_played']]
    for game_id in actions.keys():
        spadlstore[f"actions/game_{game_id}"] = actions[game_id]

# %% [markdown]
# ## Plot the spadl data
# Extra library required: ```pip install matplotsoccer```

# %%
pip install matplotsoccer

# %%
with pd.HDFStore(spadl_h5) as spadlstore:
    games = (
        spadlstore["games"]
        .merge(spadlstore["competitions"], how='left')
        .merge(spadlstore["teams"].add_prefix('home_'), how='left')
        .merge(spadlstore["teams"].add_prefix('away_'), how='left'))
    # Select England vs Belgium game at World Cup
    game = games[(games.competition_name == "FIFA World Cup") 
                  & (games.away_team_name == "England")
                  & (games.home_team_name == "Belgium")]
    game_id = game.game_id.values[0]
    actions = (
        spadlstore[f"actions/game_{game_id}"]
        .merge(spadl.actiontypes_df(), how="left")
        .merge(spadl.results_df(), how="left")
        .merge(spadl.bodyparts_df(), how="left")
        .merge(spadlstore["players"], how="left")
        .merge(spadlstore["teams"], how="left")
    )

# use nickname if available else use full name
actions["player_name"] = actions[["nickname", "player_name"]].apply(lambda x: x.iloc[0] if x.iloc[0] else x.iloc[1], axis=1)
del actions['nickname']
actions[:5]

# %%
pip install matplotlib

# %%
import matplotsoccer

# Select the 5 actions preceding the 2-0
shot = 2201
a = actions[shot-4:shot+1].copy()

# Print the game date and timestamp of the goal
g = game.iloc[0]
minute = int((a.period_id.values[0]-1) * 45 + a.time_seconds.values[0] // 60)
game_info = f"{g.game_date} {g.home_team_name} {g.home_score}-{g.away_score} {g.away_team_name} {minute + 1}'"
print(game_info)

# Plot the actions
def nice_time(row):
    minute = int((row.period_id-1)*45 +row.time_seconds // 60)
    second = int(row.time_seconds % 60)
    return f"{minute}m{second}s"

a["nice_time"] = a.apply(nice_time, axis=1)
labels = a[["nice_time", "type_name", "player_name", "team_name"]]

ax = matplotsoccer.actions(
    location=a[["start_x", "start_y", "end_x", "end_y"]],
    action_type=a.type_name,
    team= a.team_name,
    result= a.result_name == "success",
    label=labels,
    labeltitle=["time", "actiontype", "player", "team"],
    zoom=False,
    figsize=6
)
